# %% [markdown]
# # A Cognitive Model or Harmonic Types -- Amortized Version

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Thesis/probabilistic_harmony_model
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Thesis/probabilistic_harmony_model

# %%
# !pip install pyro-api==0.1.2
# !pip install pyro-ppl==1.8.4
# !pip install pitchtypes==0.4.0
# Out:
# Requirement already satisfied: pyro-api==0.1.2 in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: pyro-ppl==1.8.4 in /usr/local/lib/python3.10/dist-packages (1.8.4)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl==1.8.4) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl==1.8.4) (3.3.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl==1.8.4) (0.1.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl==1.8.4) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl==1.8.4) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl==1.8.4) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->pyro-ppl==1.8.4) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pyro-ppl==1.8.4) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pyro-ppl==1.8.4) (1.3.0)
# Requirement already satisfied: pitchtypes==0.4.0 in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pitchtypes==0.4.0) (1.25.2)

# %%
import torch
import torch.nn as nn
import pyro
import pyro.distributions as dist

from pyro.distributions import *
#from collections import Counter
import pyro.infer
import pyro.optim
import pyro.util
pyro.enable_validation(True)

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import tqdm

import numpy as np
import pandas as pd
import scipy.stats as stats

import os.path as path
from datetime import datetime
from fractions import Fraction
import json

import utils

import gc

# %%
gpu = torch.cuda.is_available()

# TODO: set the GPU you want to use
gpu_n = 0

torch.set_default_dtype(torch.float64)
device = torch.device(f'cuda:{gpu_n}' if gpu else 'cpu')
torch.set_default_device(device)
print(device)
# Out:
# cpu

# %%
def save_rng_state(name):
    fn = name + '-' + datetime.today().isoformat() + '.state'
    state = pyro.util.get_rng_state()
    with open('rng-' + fn, 'w') as f:
        print(state, file=f)
    torch.save(state['torch'], 'torch-' + fn)

# %%
# set random seeds
pyro.set_rng_seed(0)
#torch.set_deterministic(True)
#torch.set_num_threads(1)
#torch.set_num_interop_threads(1)

# fix the range of pitches we consider
fifth_range = 2*7                  # 2 diatonics
npcs = 2*fifth_range+1             # around C: Cbb to C## on LoF
utils.set_fifth_range(fifth_range) # used to make helper functions work correctly

# %% [markdown]
# # 1. Experimental Setup
#
# ## Original Model
#
# A chord consists of a number of notes,
# which are either generated as stable chord tones or as ornaments.
# We model this process by distinguishing (for each chord type)
# a distribution of chord tones and a distribution of ornaments.
# For each generated note, a coin is flipped as to whether the tone is generated as a chord tone or ornament.
# The pitch is then drawn from the corresponding distribution.
# Since we don't always know the type of a note, we flip another coin to decide whether the type is observed or not (in which case `unknown` is emitted for both ornaments and chordtones).
#
# Priors:
# - choose $\vec\chi \sim \text{Dirichlet}(0.5, n_\text{harmonies})$
# - choose $\lambda \sim \text{Gamma}(3,1)$
# - for each chord type $c$:
#   - choose $\theta_c \sim \text{Beta}(1,1)$
#   - choose $\vec\phi_{ct}^{(c)} \sim \text{Dirichlet}(0.5, n_\text{pitches})$
#   - choose $\vec\phi_{or}^{(c)} \sim \text{Dirichlet}(0.5, n_\text{pitches})$
#
# Generating a single chord (long version):
# - choose $h \sim \text{Categorical}(\vec\chi)$
# - choose $n \sim \text{Poisson}(\lambda) + 1$
# - for each note $i \in 1, \ldots, n$:
#   - choose $t_i \sim \text{Bernoulli}(\theta_h)$
#   - choose $p_i \sim \begin{cases}
#                        \text{Categorical}(\vec\phi_{ct}^{(h)}) & \text{if } t_i = 1\\
#                        \text{Categorical}(\vec\phi_{or}^{(h)}) & \text{if } t_i = 0
#                      \end{cases}$
#   - choose $o_i \sim \text{Bernoulli}(p_\text{obs})$
#   - choose $ot_i = \begin{cases}
#                      \text{'chordtone'} & \text{if } o_i = 1 \wedge p_i = 1\\
#                      \text{'ornament'} & \text{if } o_i = 1 \wedge p_i = 0\\
#                      \text{'unknown'} & \text{if } o_i = 0\\
#                    \end{cases}$
# - count $(p_i,ot_i)$ pairs
#
# Generating a single chord (compact version)
# - choose $h \sim \text{Catecorical}(\vec\chi)$
# - choose $n \sim \text{Poisson}(\lambda) + 1$
# - choose $n_{p,ot} \sim \text{Multinomial}(n, \vec\nu),$ where
#   - $\nu_{ct} = p_\text{obs} \cdot \theta \cdot \vec\phi_{ct}^{(h)}$
#   - $\nu_{or} = p_\text{obs} \cdot (1-\theta) \cdot \vec\phi_{or}^{(o)}$
#   - $\nu_{uk} = (1-p_\text{obs}) \cdot \left( \theta \vec\phi_{ct}^{(h)} + (1-\theta) \vec\phi_{or}^{(h)} \right)$
#   - $\nu = \text{concat}(\nu_{ct}, \nu_{or}, \nu_{uk})$

# %% [markdown]
# ## Adding amortization:
# At least chord types is unknown now

# %%
def chord_model(npcs, nharmonies, data, subsamples=500, pobserve=0.5, **kwargs):
    # parameters priors:
    # distribution of the harmonies
    p_harmony = pyro.sample('p_harmony', Dirichlet(0.5 * torch.ones(nharmonies, device=device)))
    # distribution of notes in the harmonies
    with pyro.plate('harmonies', nharmonies) as ind:
        # distribution of ornament probability
        p_is_chordtone = pyro.sample('p_is_chordtone', Beta(torch.ones(nharmonies, device=device), torch.ones(nharmonies, device=device)))
        #print(p_is_chordtone.shape)
        # distribution of notes per note type
        p_chordtones = pyro.sample('p_chordtones', Dirichlet(0.5 * torch.ones(npcs, device=device)))
        p_ornaments  = pyro.sample('p_ornaments', Dirichlet(0.5 * torch.ones(npcs, device=device)))
        #print(p_chordtones.shape)
        # we build a big categorical out of the chordtones and ornaments,
        # including notes of unknown type (marginalizing over the categories)
        #p_ct = p_is_chordtone       * p_chordtones
        #p_or = (1 - p_is_chordtone) * p_ornaments
        p_ct = torch.mm(torch.diag(p_is_chordtone), p_chordtones)
        p_or = torch.mm(torch.diag(1 - p_is_chordtone), p_ornaments)
        p_unobserved = p_ct + p_or
        p_tones = torch.cat([pobserve * p_ct, pobserve * p_or, (1-pobserve) * p_unobserved], dim=1)
    # distribution of note rate in chords
    rate_notes = pyro.sample('rate_notes', Gamma(torch.tensor(3., device=device),torch.tensor(1., device=device)))

    # Sampling the data:
    nchords = len(data['c'])
    with pyro.plate("chords", nchords) as ind:
    #with pyro.plate('data', nchords, subsample_size=None) as ind:
        # pick a harmony, now unkown
        # c = pyro.sample('c', Categorical(p_harmony))
        c = pyro.sample("c", dist.Categorical(torch.ones(nharmonies, device=device) / nharmonies))

        # pick a number of notes
        nnotes = 1 + pyro.sample('n', Poisson(rate_notes), obs=data['n'][ind]).int()
        # sample chordtones
        # Normally we would sample nnotes notes for each chord, but that doesn't work vectorized.
        # However, evaluating the probability ignores n, so we can just provide 1 here.
        notes = pyro.sample('chord', Multinomial(1, p_tones[c], validate_args=False), obs=data['pitches'][ind])
        chords = {'c': c,
                  'n': nnotes,
                  'counts': notes.reshape(-1,npcs)}
    return chords

# %% [markdown]
# ## Guide
#
# A simple guide that assumes the latent variables to be distributed independently.

# %%
def normalize_notes(notes):
  scale = 1/torch.max(notes, dim=1).values
  return torch.mul(notes, scale.reshape(len(scale), 1))

# %%
class AmortizedChordGuide(nn.Module):
  def __init__(self, npcs, nharmonies):
      super().__init__()
      hidden = 32
      self.f = nn.Sequential(
          nn.Linear(npcs*3, hidden),
          nn.SELU(),
          nn.Dropout(0.2),
          nn.Linear(hidden, nharmonies),
          nn.Softmax(dim=1)
      )

  def forward(self, notes):
      return self.f(normalize_notes(notes))

  def guide(self, npcs, nharmonies, nchords, data):
      pyro.module("chord_predictor", self)

      # posterior of p_harmony
      params_p_harmony = pyro.param('params_p_harmony', 0.5 * torch.ones(nharmonies, device=device), constraint=constraints.positive)
      pyro.sample('p_harmony', Dirichlet(params_p_harmony))

      # posteriors of notes dists in harmonies (parameters)
      params_p_chordtones = pyro.param('params_p_chordtones', 0.5 * torch.ones([nharmonies, npcs], device=device), constraint=constraints.positive)
      params_p_ornaments = pyro.param('params_p_ornaments', 0.5 * torch.ones([nharmonies, npcs], device=device), constraint=constraints.positive)

      # posterior of ornament probability (parameters)
      alpha_p_ict = pyro.param('alpha_p_ict', torch.ones(nharmonies, device=device), constraint=constraints.positive)
      beta_p_ict = pyro.param('beta_p_ict', torch.ones(nharmonies, device=device), constraint=constraints.positive)

      # posteriors of ornament probability and note distributions
      with pyro.plate('harmonies', nharmonies) as ind:
          pyro.sample('p_is_chordtone', Beta(alpha_p_ict, beta_p_ict))
          pyro.sample('p_chordtones', Dirichlet(params_p_chordtones))
          pyro.sample('p_ornaments', Dirichlet(params_p_ornaments))

      # posterior of note rate
      alpha_rate_notes = pyro.param('alpha_rate_notes', torch.tensor(3., device=device), constraint=constraints.positive)
      beta_rate_notes = pyro.param('beta_rate_notes', torch.tensor(1., device=device), constraint=constraints.positive)
      rate_notes = pyro.sample('rate_notes', Gamma(alpha_rate_notes, beta_rate_notes))

      # for chords
      nchords = len(data['c'])
      subs = min(500, nchords)
      with pyro.plate("chords", nchords, subsample_size=subs) as ind:
        chord_type_params = self.forward(data['pitches'][ind])
        pyro.sample("c", dist.Categorical(chord_type_params))

# %% [markdown]
# ## Data and Conditioning
#
# ### Data Format
#
# The input data (i.e. the observations that the model is conditioned on) is represented by three tensors:
# - `c` for the chord labels (as "categorical" integers)
# - `n` for the number of notes in each chord
# - `notes` for the observed notes in each chord
#
# Each of these tensors represents the values for all chords at the same time (i.e. a *vectorized* representation),
# so the first dimension of each equals `nchords`, the number of chords.
# `c` and `n` are vectors, i.e. their value for each chord is a scalar.
# `notes` represents a vector for each chord that contains the counts of all pitch $\times$ note type pairs in the chord.
# If we assume 29 pitch classes, we therefore have 87 entries: 29 for the chordtones, 29 for the ornaments, and 29 for the notes of unknown type.
# As a result, `notes` has dimension `nchords` $\times$ 87.
#
# The values of `c` represent each chord's type, which is distributed according to a categorical distribution.
# In pyro/torch, categories are represented as integers, so we must convert textual labels into integers.
# Similarly, the index of a note in `notes` is determined by it's pitch class and type (as outlined above).
# While we allow negative pitch classes, they can be easily transformed into indices (and *vice versa*) by shifting all values by `npcs // 2`.

# %%
def chord_tensor(notes):
    """Takes a list of notes as (fifth, type) pairs and returns a vector of counts."""
    notetype = {'chordtone': 0, 'ornament': 1, 'unknown': 2}
    chord = torch.zeros((3, npcs), device=device)
    for (fifth, t) in notes:
        chord[notetype[t], utils.fifth_to_index(fifth)] += 1
    return chord

def annot_data_obs(chords):
    """Helper function to turn a list of chord dictionaries into a dictionary of observation vectors."""
    obs = {}
    obs["pitches"] = torch.cat([chord_tensor(c['notes']).reshape((1,-1)) for c in chords], dim=0)
    obs["c"] = torch.tensor([c['label'] for c in chords], dtype=torch.int64, device=device)
    obs["n"] = torch.tensor([len(c['notes']) for c in chords], dtype=torch.int64, device=device)
    obs["onset"] = torch.tensor([float(Fraction(c['onset'])) for c in chords], dtype=torch.float32, device=device)
    obs["filename"] = [c['filename'] for c in chords]
    return obs

def annot_data_obs(chords):
    """Helper function to turn a list of chord dictionaries into a dictionary of observation vectors, now including chordid."""
    obs = {}
    obs["pitches"] = torch.cat([chord_tensor(c['notes']).reshape((1,-1)) for c in chords], dim=0)
    obs["c"] = torch.tensor([c['label'] for c in chords], device=device)
    obs["n"] = torch.tensor([len(c['notes']) for c in chords], device=device)  # corrected from len - 1 to len
    obs["chordid"] = torch.tensor([c['chordid'] for c in chords], device=device)  # Add chordid to observations
    return obs

# %% [markdown]
# ### Loading the Dataset
#
# The data is loaded from a TSV file that.
# The resulting dataframe is converted to the observation format that we pass to the model.

# %%
def load_dataset(filename):
    filename = path.join("data", filename)
    print("loading dataset...")
    df = utils.load_csv(filename)
    sizes = df.groupby(['chordid', 'label']).size()
    type_counts = sizes.groupby('label').size().sort_values(ascending=False)
    chordtypes = type_counts.index.tolist()
    df['numlabel'] = df.label.map(chordtypes.index)

    prefn = filename + "_precomp.pt"
    if path.exists(prefn) and path.getmtime(prefn) > path.getmtime(filename):
        print("using precomputed tensor data.")
        obs = torch.load(prefn, map_location=device)
    else:
        print('extracting chords...')
        chords = [{'label': label, 'notes': list(zip(grp.fifth, grp.type)), 'onset': grp.onset.iloc[0], 'filename': grp.filename.iloc[0]}
                  for (_, label), grp in tqdm.tqdm(df.groupby(['chordid', 'numlabel']))]
        print('converting chords to tensors...')
        obs = annot_data_obs(chords)
        torch.save(obs, prefn)

    print(len(chordtypes), "chord types")
    print(len(obs["c"]), "chords")
    return df, obs, chordtypes

# %%
def load_dataset(filename):
    filename = path.join("data", filename)
    print("loading dataset...")
    df = utils.load_csv(filename)
    sizes = df.groupby(['chordid', 'label']).size()
    type_counts = sizes.groupby('label').size().sort_values(ascending=False)
    chordtypes = type_counts.index.tolist()
    df['numlabel'] = df.label.map(chordtypes.index)

    prefn = filename + "ori_precomp.pt"
    if path.exists(prefn) and path.getmtime(prefn) > path.getmtime(filename):
        print("using precomputed tensor data.")
        obs = torch.load(prefn, map_location=device)
    else:
        print('extracting chords...')
        chords = [{'chordid': idx, 'label': label, 'notes': list(zip(grp.fifth, grp.type))}
                  for (idx, label), grp in tqdm.tqdm(df.groupby(['chordid', 'numlabel']))]
        print('converting chords to tensors...')
        obs = annot_data_obs(chords)
        torch.save(obs, prefn)

    print(len(chordtypes), "chord types")
    print(len(obs["c"]), "chords")
    return df, obs, chordtypes

# %%
def get_cluster_info(cluster_id, predictions, obs):
    cluster_indices = np.where(predictions == cluster_id)[0]

    # Fetch the data for these indices
    filenames = [obs['filename'][i] for i in cluster_indices]
    onsets = [obs['onset'][i].item() for i in cluster_indices]
    labels = [obs['c'][i].item() for i in cluster_indices]

    df_cluster = pd.DataFrame({
        'Filename': filenames,
        'Onset': onsets,
        'Label': labels
    })

    return df_cluster

def get_cluster_chords(df, predictions, cluster_id):
    cluster_chords = df[df['chordid'].isin(predictions[predictions == cluster_id].index)]
    return cluster_chords

# %% [markdown]
# After inferring the parameters we save them for easier inspection and reuse.

# %%
def save_params(params, nharmonies, npcs, name):
    # Save the PyTorch parameters and histories
    torch_params = {k: v for k, v in params.items() if k not in ['p_chordtones_history', 'p_ornaments_history']}
    torch.save(torch_params, path.join("results", name + '.pt'))

    # Save the histories separately as numpy files
    for history_key in ['p_chordtones_history', 'p_ornaments_history']:
        if history_key in params:
            np.save(path.join("results", name + '_' + history_key + '.npy'), params[history_key])

    # Save the parameters and history references in a JSON file for easy access
    with open(path.join("results", name + '.json'), 'w') as f:
        json.dump({
            'params': {key: val.tolist() for key, val in torch_params.items()},
            'histories': {key: name + '_' + key + '.npy' for key in ['p_chordtones_history', 'p_ornaments_history'] if key in params},
            'nharmonies': nharmonies,
            'npcs': npcs
        }, f)

# %% [markdown]
# ## Inference
#
# Inference of the posterior is done via variational inference, i.e. by optimizing the parameters of the guide.
# The function `infer_posteriors` takes a dataset of observations,
# performs the optimization, and returns the optimized parameters together with some of their histories.

# %% [markdown]
# **Initial Training with Uniform Prior:**
#
# In the `chord_model` function, chord types (`c`) are initially sampled from a uniform distribution: `dist.Categorical(torch.ones(nharmonies, device=device) / nharmonies)`. This setup ensures that the initial training phase does not assume any prior knowledge about the prevalence of different chord types.
#
# **Transition to Learning Chord Prevalence:**
#
# The function `infer_with_p_harmony` updates the model to incorporate learning the prevalence of chord types (`p_harmony`). In this updated model, chord types are sampled based on `p_harmony`: `dist.Categorical(p_harmony)`, which is learned from the data. This shift refines the model based on observed distributions after the initial exploration phase.

# %%
def infer_amortized_posteriors(npcs, nharmonies, obs,
                              nsteps=5000, subsamples=10000, particles=4,
                              plot_loss=True, save_as=None):
    # optimize the parameters of the guide
    pyro.clear_param_store()
    # pyro.set_rng_seed(1625) # set every time for independent reproducibility

    # create an instance of the guide
    amortized_guide = AmortizedChordGuide(npcs, nharmonies).to(device)

    svi = pyro.infer.SVI(model=chord_model,
                         guide=amortized_guide.guide,
                         optim=pyro.optim.Adam({"lr": 0.01, "betas": (0.95, 0.999), "foreach": False}),
                         #optim=pyro.optim.Adadelta({"lr": 1.0, "rho": 0.9}),
                         #optim=pyro.optim.SGD({"lr": 0.00005, "momentum": 0.9, "nesterov": True}),
                         loss=pyro.infer.Trace_ELBO(num_particles=particles))

    # set up histories for the loss and some of the parameters
    losses = np.zeros(nsteps)
    param_history = {name:np.zeros(nsteps) for name in ['alpha_rate_notes', 'beta_rate_notes']}#, 'alpha_p_ict', 'beta_p_ict']}
    root_history = np.zeros((nsteps,nharmonies))
    harm_history = np.zeros((nsteps,nharmonies))

    # run the optimization
    for i in tqdm.trange(nsteps):
        # update parameters and record loss
        losses[i] = svi.step(npcs, nharmonies, nchords=len(obs['c']), data=obs)

        # record values of some parameters
        ps = pyro.get_param_store()
        root_history[i] = ps.get_param('params_p_chordtones').cpu().detach()[:,fifth_range]
        harm_history[i] = ps.get_param('params_p_harmony').cpu().detach()

        for (name, value) in ps.items():
            if name in param_history:
                param_history[name][i] = value.cpu().item()

    # plot the loss
    if plot_loss:
        plt.figure()
        plt.plot(losses)
        plt.xlabel("iteration")
        plt.ylabel("loss")
        plt.title(f"loss ({save_as})")
        plt.show(block=False)
        print("loss variance (last 100 steps):", losses[-100:].var())

    # make predictions
    with torch.no_grad():
        pred_probs = amortized_guide.forward(obs['pitches']).cpu().numpy()

    params = dict((name, value.detach().cpu().detach().numpy()) for name, value in pyro.get_param_store().items())
    if save_as != None:
        save_params(params, nharmonies, npcs, save_as)
        np.save(f"{save_as}_stage1_predictions.npy", pred_probs)

    return params, param_history, root_history, harm_history, amortized_guide, pred_probs

# %%
def updated_model(npcs, nharmonies, data, subsamples=500, pobserve=0.5, **kwargs):
    # parameters priors:
    # distribution of the harmonies
    p_harmony = pyro.sample('p_harmony', Dirichlet(0.5 * torch.ones(nharmonies, device=device)))
    # distribution of notes in the harmonies
    with pyro.plate('harmonies', nharmonies) as ind:
        # distribution of ornament probability
        p_is_chordtone = pyro.sample('p_is_chordtone', Beta(torch.ones(nharmonies, device=device), torch.ones(nharmonies, device=device)))
        #print(p_is_chordtone.shape)
        # distribution of notes per note type
        p_chordtones = pyro.sample('p_chordtones', Dirichlet(0.5 * torch.ones(npcs, device=device)))
        p_ornaments  = pyro.sample('p_ornaments', Dirichlet(0.5 * torch.ones(npcs, device=device)))
        #print(p_chordtones.shape)
        # we build a big categorical out of the chordtones and ornaments,
        # including notes of unknown type (marginalizing over the categories)
        #p_ct = p_is_chordtone       * p_chordtones
        #p_or = (1 - p_is_chordtone) * p_ornaments
        p_ct = torch.mm(torch.diag(p_is_chordtone), p_chordtones)
        p_or = torch.mm(torch.diag(1 - p_is_chordtone), p_ornaments)
        p_unobserved = p_ct + p_or
        p_tones = torch.cat([pobserve * p_ct, pobserve * p_or, (1-pobserve) * p_unobserved], dim=1)
    # distribution of note rate in chords
    rate_notes = pyro.sample('rate_notes', Gamma(torch.tensor(3., device=device),torch.tensor(1., device=device)))

    # Sampling the data:
    nchords = len(data['c'])
    with pyro.plate("chords", nchords) as ind:
    #with pyro.plate('data', nchords, subsample_size=None) as ind:
        # pick a harmony, now unkown
        c = pyro.sample('c', Categorical(p_harmony))
        nnotes = 1 + pyro.sample('n', Poisson(rate_notes), obs=data['n'][ind]).int()
        notes = pyro.sample('chord', Multinomial(1, p_tones[c], validate_args=False), obs=data['pitches'][ind])
        chords = {'c': c,
                  'n': nnotes,
                  'counts': notes.reshape(-1,npcs)}
    return chords

# %%
def infer_with_p_harmony(npcs, nharmonies, obs, trained_network,
                         nsteps=5000, subsamples=500,
                         plot_loss=True, save_as=None):

    # use network from the first traning stage
    pyro.clear_param_store()
    amortized_guide = trained_network

    svi = pyro.infer.SVI(model=updated_model,
                         guide=amortized_guide.guide,
                         optim=pyro.optim.Adam({"lr": 0.01, "betas": (0.95, 0.999), "foreach": False}),
                         loss=pyro.infer.Trace_ELBO(num_particles=4))

    # set up histories for the loss and some of the parameters
    losses = np.zeros(nsteps)
    param_history = {name:np.zeros(nsteps) for name in ['alpha_rate_notes', 'beta_rate_notes']}#, 'alpha_p_ict', 'beta_p_ict']}
    root_history = np.zeros((nsteps,nharmonies))
    harm_history = np.zeros((nsteps,nharmonies))

    # run the optimization
    for i in tqdm.trange(nsteps):
        # update parameters and record loss
        losses[i] = svi.step(npcs, nharmonies, nchords=len(obs['c']), data=obs)

        # record values of some parameters
        ps = pyro.get_param_store()
        root_history[i] = ps.get_param('params_p_chordtones').cpu().detach()[:,fifth_range]
        harm_history[i] = ps.get_param('params_p_harmony').cpu().detach()

        for (name, value) in ps.items():
            if name in param_history:
                param_history[name][i] = value.cpu().item()

    # plot the loss
    if plot_loss:
        plt.figure()
        plt.plot(losses)
        plt.xlabel("iteration")
        plt.ylabel("loss")
        plt.title(f"loss ({save_as})")
        plt.show(block=False)
        print("loss variance (last 100 steps):", losses[-100:].var())

    params = dict((name, value.detach().cpu().detach().numpy()) for name, value in pyro.get_param_store().items())
    if save_as != None:
        save_params(params, nharmonies, npcs, save_as)

    return params, param_history, root_history, harm_history

# %% [markdown]
# ## Plotting
#
# To inspect the results and the behaviour of the optimization, we define some functions for plotting parameter histories and posterior distributions.

# %%
# histories

# several parameters
def plot_params_history(name, ax, history):
    df = pd.DataFrame(history)
    df.plot(ax=ax)
    ax.set_title(f"history ({name})")
    ax.set_xlabel("iteration")

# single parameter
def plot_param_history(name, ax, root_history, ylabel):
    ax.plot(root_history)
    ax.set_xlabel("iteration")
    ax.set_ylabel(ylabel)
    ax.set_title(f"{ylabel} ({name})")

# all parameters
def plot_histories(name, param_history, root_history, harm_history):
    fig, ax = plt.subplots(1,3, figsize=(9,3))
    plot_params_history(name, ax[0], param_history)
    plot_param_history(name, ax[1], root_history, 'root parameters')
    plot_param_history(name, ax[2], harm_history, 'chord-type parameters')
    fig.tight_layout()
    plt.show(block=False)

# %%
# posteriors

# posterior of 'rate_notes'
def plot_note_rate(name, ax1, ax2, params, lower=0, upper=10):
    #fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9,3))

    alpha = params['alpha_rate_notes']
    beta = params['beta_rate_notes']
    x = np.linspace(lower, upper, 200)
    y = stats.gamma.pdf(x, alpha, scale=1/beta)
    ax1.plot(x,y)
    ax1.set_xlabel('rate_notes')
    ax1.set_title(f'note rate distribution ({name})')

    xrate = torch.linspace(0,15,16)
    yrate = stats.nbinom.pmf(xrate, alpha, 1/(1+1/beta))
    ax2.bar(xrate+1, yrate)
    ax2.set_xlabel('nnotes')
    ax2.set_title(f'expected notes per chord distribution ({name})')

    #fig.tight_layout()
    #plt.show(block=False)

def plot_note_rates(name, phist, n=100, lower=0, upper=10):
    alphas = phist['alpha_rate_notes'][-n:]
    betas = phist['beta_rate_notes'][-n:]
    x = np.linspace(lower, upper, 200)
    ys = np.array([stats.gamma.pdf(x, a, scale=1/b) for (a,b) in zip(alphas,betas)]).transpose()
    plt.plot(x,ys, color='steelblue', alpha=0.5)
    plt.xlabel(f'rate_notes (last {n} iterations)')
    plt.title(f'note rate history ({name})')
    plt.show(block=False)

# posterior of 'p_is_chordtone'
def plot_p_ict(name, ax, params, harmtypes, lower=0, upper=1):
    #plt.figure(figsize=(9,3))
    alphas = params["alpha_p_ict"]
    betas  = params["beta_p_ict"]
    x = torch.linspace(lower, upper, 200)
    y = np.array([stats.beta.pdf(x, a, b) for a, b in zip(alphas, betas)]).transpose()
    ax.plot(x,y)
    ax.set_xlabel("p_is_chordtone")
    ax.legend(harmtypes, bbox_to_anchor=(0.5,1.1), loc='lower center', ncols=4)
    ax.set_title(f"posteriors of 'p_is_chordtone' ({name})")
    #plt.show(block=False)

# posterior of chord type probabilities
def plot_chord_type_dist(name, ax, params):
    alphas = params['params_p_harmony']
    labels = [f'Chord {i+1}' for i in range(len(alphas))]
    ax.barh(range(len(alphas)), alphas, tick_label=labels)
    ax.invert_yaxis()
    ax.set_xlabel("params_p_harmony")
    ax.set_title(f'Chord-type distribution ({name})')

# posteriors of note probabilities
def plot_chords(name, params):
    post_chordtones = params['params_p_chordtones']
    post_ornaments = params['params_p_ornaments']
    for i in range(len(post_chordtones)):
        utils.plot_profile(post_chordtones[i], post_ornaments[i], f"Chord {i+1} ({name})")
        utils.play_chord(post_chordtones[i])

# plot all posteriors
def plot_posteriors(name, params, rate_range=(0,10), ict_range=(0,1)):
    fig = plt.figure(constrained_layout=True, figsize=(9,12))
    axs = fig.subplot_mosaic([
            ["rate", "types"],
            ["nnotes", "types"],
            ["ict", "ict"]])

    plot_note_rate(name, axs['rate'], axs['nnotes'], params, lower=rate_range[0], upper=rate_range[1])
    plot_chord_type_dist(name, axs['types'], params)
    plot_p_ict(name, axs['ict'], params, [f'Chord {i+1}' for i in range(len(params['params_p_harmony']))], lower=ict_range[0], upper=ict_range[1])

    fig.tight_layout()
    plt.show(block=False)

# %%
# transition matrix
def plot_transition_matrix(preds_stage1, preds_stage2, n_chordtypes):
    matrix = np.zeros((n_chordtypes, n_chordtypes))
    for before, after in zip(preds_stage1, preds_stage2):
        matrix[before, after] += 1

    # normalize the matrix
    matrix /= matrix.sum(axis=1, keepdims=True)

    plt.figure(figsize=(15, 12))
    sns.heatmap(matrix, annot=True, fmt=".2f", cmap="Blues", xticklabels=range(1, n_chordtypes+1), yticklabels=range(1, n_chordtypes+1))
    plt.title("Transition Matrix from Stage 1 to Stage 2 Training")
    plt.xlabel("Chord Type After Stage 2")
    plt.ylabel("Chord Type After Stage 1")
    plt.show()

# %%
def calculate_entropy(distributions):
    normalized_distributions = distributions / distributions.sum(axis=1, keepdims=True)
    entropy = -np.sum(normalized_distributions * np.log(normalized_distributions + 1e-9), axis=1)
    return entropy

def plot_entropy(entropy, title="Entropy over Time"):
    plt.figure(figsize=(10, 6))
    plt.plot(entropy, label="Entropy")
    plt.xlabel("Time Step")
    plt.ylabel("Entropy")
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# # 2. Experiments
#
# ## DCML Corpus
#
# The DCML corpus is a collection of classical pieces with elaborate harmonic annotations.
# Here we only distinguish the basic harmonic types defined in the annotation standard (triads and seventh chords),
# since the extra information (inversion, suspensions, added notes etc.) do not change the type of the chord.

# %%
# ! python preprocess_dcml.py

# %%
# prepare the dataset
dcml_df, dcml_obs, dcml_chordtypes = load_dataset('dcml2.tsv')
# Out:
# loading dataset...
# using precomputed tensor data.
# 14 chord types
# 113771 chords

# %%
# run the optimization
cluster = 14
dcml_params, dhist, droots, dharm, amortized_guide, preds_stage1 = infer_amortized_posteriors(npcs, cluster, dcml_obs,
                                                                                nsteps=10000, subsamples=None, particles=1,
                                                                                save_as="dcml_params")
preds_stage1 = np.argmax(preds_stage1, axis=1)
# Out:
# 100%|██████████| 10000/10000 [03:10<00:00, 52.56it/s]
# loss variance (last 100 steps): 12399218028.75283

# %%
dcml_params_stage2, dhist2, droots2, dharm2 = infer_with_p_harmony(npcs, cluster, dcml_obs, amortized_guide,
                                                                  nsteps=50000, subsamples=None,
                                                                  plot_loss=True, save_as="dcml_params_stage2")
# Out:
# 100%|██████████| 50000/50000 [57:46<00:00, 14.43it/s]
# loss variance (last 100 steps): 3573763544.6083784

# %%
def predict_chord_types(amortized_guide, obs):
    with torch.no_grad():
        pred_probs = amortized_guide.forward(obs['pitches']).cpu().numpy()
    return np.argmax(pred_probs, axis=1)

preds_stage2 = predict_chord_types(amortized_guide, dcml_obs)

# %%
# plot the histories the parameters to check convergence
plot_histories("DCML", dhist, droots, dharm)

# %%
plot_histories("DCML", dhist2, droots2, dharm2)

# %%
# plot the posterior distributions of the parameters
plot_posteriors("DCML", dcml_params, rate_range=(6.5,6.7), ict_range=(0.7,1))
# plot_chords("DCML", dcml_params)
# Out:
# <ipython-input-20-9dcf8fb36e0f>:76: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %%
plot_posteriors("DCML", dcml_params_stage2, rate_range=(6.5,6.7), ict_range=(0.7,1))
plot_chords("DCML", dcml_params_stage2)
# Out:
# <ipython-input-20-9dcf8fb36e0f>:76: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### **Onset and Filename Information**

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 1)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 66            6     m     -3  chordtone   19/4
# 67            6     m      1  chordtone   19/4
# 68            6     m      0  chordtone   19/4
# 69            6     m      0  chordtone   19/4
# 70            7     m     -3  chordtone      5
# ...         ...   ...    ...        ...    ...
# 863758   113620     m      0  chordtone  249/4
# 863759   113620     m     -3  chordtone  249/4
# 863760   113620     m      1  chordtone  249/4
# 863761   113620     m      3   ornament  249/4
# 863762   113620     m      0  chordtone  249/4
#
#                                                  filename  numlabel
# 66                     data/dcml_corpora/ABC n01op18-1_01         2
# 67                     data/dcml_corpora/ABC n01op18-1_01         2
# 68                     data/dcml_corpora/ABC n01op18-1_01         2
# 69                     data/dcml_corpora/ABC n01op18-1_01         2
# 70                     data/dcml_corpora/ABC n01op18-1_01         2
# ...                                                   ...       ...
# 863758  data/romantic_piano_corpus/tchaikovsky_seasons...         2
# 863759  data/romantic_piano_corpus/tchaikovsky_seasons...         2
# 863760  data/romantic_piano_corpus/tchaikovsky_seasons...         2
# 863761  data/romantic_piano_corpus/tchaikovsky_seasons...         2
# 863762  data/romantic_piano_corpus/tchaikovsky_seasons...         2
#
# [118641 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 2)

print(cluster_chords)
# Out:
#         chordid label  fifth       type onset  \
# 576          47     M      1  chordtone    30
# 577          47     M      2   ornament    30
# 578          47     M      5   ornament    30
# 579          47     M      2   ornament    30
# 580          47     M      5   ornament    30
# ...         ...   ...    ...        ...   ...
# 863166   113554    Fr     -2  chordtone  97/4
# 863167   113554    Fr      2   ornament  97/4
# 863168   113554    Fr      4  chordtone  97/4
# 863169   113554    Fr      8  chordtone  97/4
# 863170   113554    Fr      2   ornament  97/4
#
#                                                  filename  numlabel
# 576                    data/dcml_corpora/ABC n01op18-1_01         0
# 577                    data/dcml_corpora/ABC n01op18-1_01         0
# 578                    data/dcml_corpora/ABC n01op18-1_01         0
# 579                    data/dcml_corpora/ABC n01op18-1_01         0
# 580                    data/dcml_corpora/ABC n01op18-1_01         0
# ...                                                   ...       ...
# 863166  data/romantic_piano_corpus/tchaikovsky_seasons...        11
# 863167  data/romantic_piano_corpus/tchaikovsky_seasons...        11
# 863168  data/romantic_piano_corpus/tchaikovsky_seasons...        11
# 863169  data/romantic_piano_corpus/tchaikovsky_seasons...        11
# 863170  data/romantic_piano_corpus/tchaikovsky_seasons...        11
#
# [32399 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 3)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 246          31     m     -3  chordtone   39/2
# 247          31     m      5    unknown   39/2
# 248          31     m     -1   ornament   39/2
# 249          31     m      1  chordtone   39/2
# 250          31     m     -4   ornament   39/2
# ...         ...   ...    ...        ...    ...
# 864366   113742   mm7      0    unknown  451/4
# 864367   113742   mm7      0    unknown  451/4
# 864368   113742   mm7     -3  chordtone  451/4
# 864369   113742   mm7      1  chordtone  451/4
# 864370   113742   mm7     -2    unknown  451/4
#
#                                                  filename  numlabel
# 246                    data/dcml_corpora/ABC n01op18-1_01         2
# 247                    data/dcml_corpora/ABC n01op18-1_01         2
# 248                    data/dcml_corpora/ABC n01op18-1_01         2
# 249                    data/dcml_corpora/ABC n01op18-1_01         2
# 250                    data/dcml_corpora/ABC n01op18-1_01         2
# ...                                                   ...       ...
# 864366  data/romantic_piano_corpus/tchaikovsky_seasons...         5
# 864367  data/romantic_piano_corpus/tchaikovsky_seasons...         5
# 864368  data/romantic_piano_corpus/tchaikovsky_seasons...         5
# 864369  data/romantic_piano_corpus/tchaikovsky_seasons...         5
# 864370  data/romantic_piano_corpus/tchaikovsky_seasons...         5
#
# [49761 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 5)

print(cluster_chords)
# Out:
#         chordid label  fifth       type   onset  \
# 31566      3493     M      4  chordtone       0
# 41166      4791     +      0  chordtone  1461/8
# 41167      4791     +      4  chordtone  1461/8
# 41168      4791     +      4  chordtone  1461/8
# 41169      4791     +      8  chordtone  1461/8
# ...         ...   ...    ...        ...     ...
# 849825   111585   Mm7      0  chordtone      32
# 849826   111585   Mm7      4  chordtone      32
# 849827   111585   Mm7      2   ornament      32
# 849828   111585   Mm7      4  chordtone      32
# 849829   111585   Mm7      8  chordtone      32
#
#                                                  filename  numlabel
# 31566                  data/dcml_corpora/ABC n03op18-3_03         0
# 41166                  data/dcml_corpora/ABC n04op18-4_01         9
# 41167                  data/dcml_corpora/ABC n04op18-4_01         9
# 41168                  data/dcml_corpora/ABC n04op18-4_01         9
# 41169                  data/dcml_corpora/ABC n04op18-4_01         9
# ...                                                   ...       ...
# 849825  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 849826  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 849827  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 849828  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 849829  data/romantic_piano_corpus/tchaikovsky_seasons...         1
#
# [333 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 6)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 140          14    o7      0    unknown   39/4
# 141          14    o7     -9    unknown   39/4
# 142          14    o7     -3  chordtone   39/4
# 143          14    o7     -4   ornament   39/4
# 144          15    o7      0    unknown   41/4
# ...         ...   ...    ...        ...    ...
# 864518   113768   Ger     -9    unknown  499/4
# 864519   113768   Ger    -10  chordtone  499/4
# 864520   113768   Ger     -6  chordtone  499/4
# 864521   113768   Ger     -9    unknown  499/4
# 864522   113768   Ger    -10  chordtone  499/4
#
#                                                  filename  numlabel
# 140                    data/dcml_corpora/ABC n01op18-1_01         4
# 141                    data/dcml_corpora/ABC n01op18-1_01         4
# 142                    data/dcml_corpora/ABC n01op18-1_01         4
# 143                    data/dcml_corpora/ABC n01op18-1_01         4
# 144                    data/dcml_corpora/ABC n01op18-1_01         4
# ...                                                   ...       ...
# 864518  data/romantic_piano_corpus/tchaikovsky_seasons...         8
# 864519  data/romantic_piano_corpus/tchaikovsky_seasons...         8
# 864520  data/romantic_piano_corpus/tchaikovsky_seasons...         8
# 864521  data/romantic_piano_corpus/tchaikovsky_seasons...         8
# 864522  data/romantic_piano_corpus/tchaikovsky_seasons...         8
#
# [82860 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 7)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 198          24     M      1  chordtone     15
# 199          24     M      3   ornament     15
# 200          24     M      1  chordtone     15
# 201          24     M      6   ornament     15
# 202          24     M      1  chordtone     15
# ...         ...   ...    ...        ...    ...
# 864490   113764     M      5  chordtone  489/4
# 864491   113764     M      5  chordtone  489/4
# 864492   113764     M      4  chordtone  489/4
# 864493   113764     M      1  chordtone  489/4
# 864494   113764     M      4  chordtone  489/4
#
#                                                  filename  numlabel
# 198                    data/dcml_corpora/ABC n01op18-1_01         0
# 199                    data/dcml_corpora/ABC n01op18-1_01         0
# 200                    data/dcml_corpora/ABC n01op18-1_01         0
# 201                    data/dcml_corpora/ABC n01op18-1_01         0
# 202                    data/dcml_corpora/ABC n01op18-1_01         0
# ...                                                   ...       ...
# 864490  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864491  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864492  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864493  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864494  data/romantic_piano_corpus/tchaikovsky_seasons...         0
#
# [42211 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 8)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 76            8     M      0  chordtone   21/4
# 77            8     M      0  chordtone   21/4
# 78            8     M     -1  chordtone   21/4
# 79            8     M      3    unknown   21/4
# 80            8     M      5   ornament   21/4
# ...         ...   ...    ...        ...    ...
# 864526   113769     M      0  chordtone  501/4
# 864527   113769     M      3  chordtone  501/4
# 864528   113769     M     -1  chordtone  501/4
# 864529   113769     M      0  chordtone  501/4
# 864530   113769     M      3  chordtone  501/4
#
#                                                  filename  numlabel
# 76                     data/dcml_corpora/ABC n01op18-1_01         0
# 77                     data/dcml_corpora/ABC n01op18-1_01         0
# 78                     data/dcml_corpora/ABC n01op18-1_01         0
# 79                     data/dcml_corpora/ABC n01op18-1_01         0
# 80                     data/dcml_corpora/ABC n01op18-1_01         0
# ...                                                   ...       ...
# 864526  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864527  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864528  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864529  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864530  data/romantic_piano_corpus/tchaikovsky_seasons...         0
#
# [50458 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 9)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 942          91    o7     -5  chordtone  201/4
# 943          91    o7     -2    unknown  201/4
# 944          91    o7     -8  chordtone  201/4
# 945          91    o7     -4    unknown  201/4
# 946          92    o7     -5  chordtone  101/2
# ...         ...   ...    ...        ...    ...
# 861864   113442    o7    -10    unknown     40
# 861865   113442    o7     -5    unknown     40
# 861866   113442    o7     -7    unknown     40
# 861867   113442    o7     -4  chordtone     40
# 861868   113442    o7    -10    unknown     40
#
#                                                  filename  numlabel
# 942                    data/dcml_corpora/ABC n01op18-1_01         4
# 943                    data/dcml_corpora/ABC n01op18-1_01         4
# 944                    data/dcml_corpora/ABC n01op18-1_01         4
# 945                    data/dcml_corpora/ABC n01op18-1_01         4
# 946                    data/dcml_corpora/ABC n01op18-1_01         4
# ...                                                   ...       ...
# 861864  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 861865  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 861866  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 861867  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 861868  data/romantic_piano_corpus/tchaikovsky_seasons...         4
#
# [19511 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 11)

print(cluster_chords)
# Out:
#         chordid label  fifth       type onset  \
# 0             0     M      0  chordtone     0
# 1             0     M      0  chordtone     0
# 2             0     M      0  chordtone     0
# 3             0     M      0  chordtone     0
# 4             0     M      2   ornament     0
# ...         ...   ...    ...        ...   ...
# 864604   113770     M      4  chordtone   126
# 864605   113770     M      1  chordtone   126
# 864606   113770     M      0  chordtone   126
# 864607   113770     M      4  chordtone   126
# 864608   113770     M      0  chordtone   126
#
#                                                  filename  numlabel
# 0                      data/dcml_corpora/ABC n01op18-1_01         0
# 1                      data/dcml_corpora/ABC n01op18-1_01         0
# 2                      data/dcml_corpora/ABC n01op18-1_01         0
# 3                      data/dcml_corpora/ABC n01op18-1_01         0
# 4                      data/dcml_corpora/ABC n01op18-1_01         0
# ...                                                   ...       ...
# 864604  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864605  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864606  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864607  data/romantic_piano_corpus/tchaikovsky_seasons...         0
# 864608  data/romantic_piano_corpus/tchaikovsky_seasons...         0
#
# [402622 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 12)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 612          49     M      5  chordtone     33
# 613          49     M      2   ornament     33
# 614          49     M      2   ornament     33
# 615          49     M      4  chordtone     33
# 1779        143     M      4  chordtone  171/2
# ...         ...   ...    ...        ...    ...
# 864299   113735   Mm7     13  chordtone  429/4
# 864300   113735   Mm7     10    unknown  429/4
# 864301   113735   Mm7      4    unknown  429/4
# 864302   113735   Mm7      7    unknown  429/4
# 864303   113735   Mm7     12    unknown  429/4
#
#                                                  filename  numlabel
# 612                    data/dcml_corpora/ABC n01op18-1_01         0
# 613                    data/dcml_corpora/ABC n01op18-1_01         0
# 614                    data/dcml_corpora/ABC n01op18-1_01         0
# 615                    data/dcml_corpora/ABC n01op18-1_01         0
# 1779                   data/dcml_corpora/ABC n01op18-1_01         0
# ...                                                   ...       ...
# 864299  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 864300  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 864301  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 864302  data/romantic_piano_corpus/tchaikovsky_seasons...         1
# 864303  data/romantic_piano_corpus/tchaikovsky_seasons...         1
#
# [25727 rows x 7 columns]

# %%
predictions = pd.Series(preds_stage2)
cluster_chords = get_cluster_chords(dcml_df, predictions, 13)

print(cluster_chords)
# Out:
#         chordid label  fifth       type  onset  \
# 546          46     m      2    unknown  117/4
# 547          46     m      1  chordtone  117/4
# 548          46     m      2    unknown  117/4
# 549          46     m      1  chordtone  117/4
# 550          46     m     -2  chordtone  117/4
# ...         ...   ...    ...        ...    ...
# 863147   113552    o7     -2  chordtone   91/4
# 863148   113552    o7     -5    unknown   91/4
# 863149   113552    o7      1  chordtone   91/4
# 863150   113552    o7     -2  chordtone   91/4
# 863151   113552    o7      4    unknown   91/4
#
#                                                  filename  numlabel
# 546                    data/dcml_corpora/ABC n01op18-1_01         2
# 547                    data/dcml_corpora/ABC n01op18-1_01         2
# 548                    data/dcml_corpora/ABC n01op18-1_01         2
# 549                    data/dcml_corpora/ABC n01op18-1_01         2
# 550                    data/dcml_corpora/ABC n01op18-1_01         2
# ...                                                   ...       ...
# 863147  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 863148  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 863149  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 863150  data/romantic_piano_corpus/tchaikovsky_seasons...         4
# 863151  data/romantic_piano_corpus/tchaikovsky_seasons...         4
#
# [40086 rows x 7 columns]

# %% [markdown]
# ### **Confusion Matrix**

# %%
dcml_chordtype_map = {
    "Fr": "French-6th",
    "Ger": "Germen-6th",
    "It": "Italian-6th",
    "M": "major",
    "m": "minor",
    "Mm7": "dominant-7th",
    "o": "diminished",
    "o7": "full-diminished",
    "mm7": "minor-7th",
    "%7": "half-diminished",
    "MM7": "major-7th",
    "+": "augmented",
    "mM7": "minor-major-7th",
    "+7": "augmented-7th",
}

# %%
cluster_names = {
    0: "Cluster 1",
    1: "Cluster 2",
    2: "Cluster 3",
    3: "Cluster 4",
    4: "Cluster 5",
    5: "Cluster 6",
    6: "Cluster 7",
    7: "Cluster 8",
    8: "Cluster 9",
    9: "Cluster 10",
    10: "Cluster 11",
    11: "Cluster 12",
    12: "Cluster 13",
    13: "Cluster 14",
}

# %%
uni_chords = dcml_df.drop_duplicates(subset=['chordid']).copy()
if 'chordid' in uni_chords.columns:
    uni_chords.set_index('chordid', inplace=True)
uni_chords.loc[:, 'predicted_chord_type'] = [cluster_names[pred] for pred in preds_stage2]
uni_chords['label'] = uni_chords['label'].apply(lambda x: dcml_chordtype_map.get(x, x))

conf_matrix = pd.crosstab(uni_chords['predicted_chord_type'], uni_chords['label'], normalize='index')
plt.figure(figsize=(12, 10))
ax = sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt=".2%", cbar=True)
plt.title('Confusion Matrix of Predicted Chord Types vs. Original Labels')
plt.xlabel('Original Labels')
plt.ylabel('Predicted Chord Types')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=10)
plt.tight_layout()
plt.show()

# %%
uni_chords = dcml_df.drop_duplicates(subset=['chordid']).copy()
if 'chordid' in uni_chords.columns:
    uni_chords.set_index('chordid', inplace=True)
uni_chords.loc[:, 'predicted_chord_type'] = [cluster_names[pred] for pred in preds_stage2]
uni_chords['label'] = uni_chords['label'].apply(lambda x: dcml_chordtype_map.get(x, x))

conf_matrix = pd.crosstab(uni_chords['predicted_chord_type'], uni_chords['label'], normalize='columns')

plt.figure(figsize=(12, 10))
ax = sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt=".2%", cbar=True)
plt.title('Confusion Matrix of Predicted Chord Types vs. Original Labels')
plt.xlabel('Original Labels')
plt.ylabel('Predicted Chord Types')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Entropy**

# %%
entropy2 = calculate_entropy(dharm2)
plot_entropy(entropy2, "Entropy of Chord Distribution Over Time")

# %% [markdown]
# ### **Transition Matrix**
#
# **Rows**: Each row corresponds to a specific chord type after Stage 1 of training.
#
# **Columns**: Each column corresponds to a specific chord type after Stage 2 of training.
#
# **Cells:** The value in each cell represents the normalized count (or probability) of a chord type from Stage 1 being classified as a certain chord type in Stage 2. A high value (closer to 1) indicates a high probability or frequency of that transition, while a low value (closer to 0) indicates a low probability or frequency.
#
# **Diagonal Cells**: Cells along the diagonal (from top left to bottom right) represent chord types that remained the same from Stage 1 to Stage 2.
#
# **Off-Diagonal Cells**: Cells off the diagonal show chord types that have changed classification from Stage 1 to Stage 2.

# %%
plot_transition_matrix(preds_stage1, preds_stage2, n_chordtypes=cluster)
# Out:
# <ipython-input-21-dbd3125489be>:8: RuntimeWarning: invalid value encountered in divide
#   matrix /= matrix.sum(axis=1, keepdims=True)
